# %%
import os

import wave
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
import librosa
import librosa.display
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

# %%
audio_data = r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\audio_and_txt_files/'

# %%
patient_data=pd.read_csv(r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\patient_diagnosis.csv',names=['pid','disease'])

# %%
diagnosis_df = pd.read_csv(r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\patient_diagnosis.csv', names=['patient_id', 'disease'])
diagnosis_df.head(10)
# Out:
#    patient_id  disease
# 0         101     URTI
# 1         102  Healthy
# 2         103   Asthma
# 3         104     COPD
# 4         105     URTI
# 5         106     COPD
# 6         107     COPD
# 7         108     LRTI
# 8         109     COPD
# 9         110     COPD

# %%
print (diagnosis_df.disease.value_counts())
print ('')
print (diagnosis_df.disease.value_counts(normalize=True) *100)
# Out:
# disease
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: count, dtype: int64
#
# disease
# COPD              50.793651
# Healthy           20.634921
# URTI              11.111111
# Bronchiectasis     5.555556
# Pneumonia          4.761905
# Bronchiolitis      4.761905
# LRTI               1.587302
# Asthma             0.793651
# Name: proportion, dtype: float64

# %%
sns.countplot(x='disease', hue='disease', data=diagnosis_df)
plt.grid(axis='y', color='green', linestyle='--', linewidth=0.5)
plt.xticks(rotation=90) 
plt.show()

# %%
path=r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\audio_and_txt_files'
files=[s.split('.')[0] for s in os.listdir(path) if '.txt' in s]

# %%
files[:15]
# Out:
# ['101_1b1_Al_sc_Meditron',
#  '101_1b1_Pr_sc_Meditron',
#  '102_1b1_Ar_sc_Meditron',
#  '103_2b2_Ar_mc_LittC2SE',
#  '104_1b1_Al_sc_Litt3200',
#  '104_1b1_Ar_sc_Litt3200',
#  '104_1b1_Ll_sc_Litt3200',
#  '104_1b1_Lr_sc_Litt3200',
#  '104_1b1_Pl_sc_Litt3200',
#  '104_1b1_Pr_sc_Litt3200',
#  '105_1b1_Tc_sc_Meditron',
#  '106_2b1_Pl_mc_LittC2SE',
#  '106_2b1_Pr_mc_LittC2SE',
#  '107_2b3_Al_mc_AKGC417L',
#  '107_2b3_Ar_mc_AKGC417L']

# %%
print(f"Librosa version: {librosa.__version__}")
print(f"Librosa location: {librosa.__file__}")
# Out:
# Librosa version: 0.10.2.post1
# Librosa location: C:\Users\saive\.anaconda\New folder\Lib\site-packages\librosa\__init__.py

# %%
def add_noise(data,x):
    noise = np.random.randn(len(data))
    data_noise = data + x * noise
    return data_noise

def shift(data,x):
    return np.roll(data, x)

def stretch(data, rate):
    data = librosa.effects.time_stretch(data, rate=1.0)
    return data

def pitch_shift (data , rate):
    data = librosa.effects.pitch_shift(data, sr=220250, n_steps=rate)
    return data

# %%
def show_audio(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.waveshow(y, sr=sr)
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.waveshow(y_noise, sr=sr)
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.waveshow(y_shift, sr=sr)
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.waveshow(y_stretch_1, sr=sr)
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.waveshow(y_stretch_2, sr=sr)
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.waveshow(y_pitch_shift, sr=sr)
    plt.title('pitch shift')

    plt.tight_layout()

# %%
show_audio(r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\audio_and_txt_files\104_1b1_Lr_sc_Litt3200.wav')

# %%
def show_audio_features(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    y = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=50)
    y_noise = librosa.feature.mfcc(y=y_noise, sr=sr, n_mfcc=50)
    y_shift = librosa.feature.mfcc(y=y_shift, sr=sr, n_mfcc=50)
    y_stretch_1 = librosa.feature.mfcc(y=y_stretch_1, sr=sr, n_mfcc=50)
    y_stretch_2 = librosa.feature.mfcc(y=y_stretch_2, sr=sr, n_mfcc=50)
    y_pitch_shift = librosa.feature.mfcc(y=y_pitch_shift, sr=sr, n_mfcc=50)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.specshow(librosa.power_to_db(y,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.specshow(librosa.power_to_db(y_noise,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.specshow(librosa.power_to_db(y_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.specshow(librosa.power_to_db(y_stretch_1,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.specshow(librosa.power_to_db(y_stretch_2,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.specshow(librosa.power_to_db(y_pitch_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('pitch shift')
    
    

    plt.tight_layout()

# %%
show_audio_features(r'C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\audio_and_txt_files\104_1b1_Lr_sc_Litt3200.wav')

# %%
def mfccs_feature_exteraction(dir_):

    X_=[]
    y_=[]
    
    COPD=[]
    copd_count=0
    
    data = diagnosis_df
    features = 52
    
    for soundDir in (os.listdir(dir_)):
        if soundDir[-3:]=='wav'and soundDir[:3]!='103'and soundDir[:3]!='108'and soundDir[:3]!='115':

            p = list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0]
            if (p=='COPD'):
                if (soundDir[:6] in COPD) and copd_count<2:
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    COPD.append(soundDir[:6])
                    copd_count+=1
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                    
                if (soundDir[:6] not in COPD):
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    COPD.append(soundDir[:6])
                    copd_count=0
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                
            if (p!='COPD'):
                if ((p == 'Bronchiectasis') or (p == 'Bronchiolitis')):
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs)
                    y_.append('Bronchiolitis')
            
                    data_noise = add_noise(data_x,0.001)
                    mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_noise)
                    y_.append('Bronchiolitis')

                    data_shift = shift(data_x,1600)
                    mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_shift)
                    y_.append('Bronchiolitis')
                    
                    data_stretch = stretch(data_x,1.2)
                    mfccs_stretch = np.mean(librosa.feature.mfcc(y=data_stretch, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append('Bronchiolitis')
                    
                    data_stretch_2 = stretch(data_x,0.8)
                    mfccs_stretch_2 = np.mean(librosa.feature.mfcc(y=data_stretch_2, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch_2)
                    y_.append('Bronchiolitis')
                    
                    data_pitch_shift = pitch_shift(data_x,3)
                    mfccs_stretch = np.mean(librosa.feature.melspectrogram(y=data_pitch_shift, sr=sampling_rate, n_mels=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append('Bronchiolitis')
                    
                else: 
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
            
                    data_noise = add_noise(data_x,0.001)
                    mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_noise)
                    y_.append(p)

                    data_shift = shift(data_x,1600)
                    mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_shift)
                    y_.append(p)
                    
                    data_stretch = stretch(data_x,1.2)
                    mfccs_stretch = np.mean(librosa.feature.mfcc(y=data_stretch, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append(p)
                    
                    data_stretch_2 = stretch(data_x,0.8)
                    mfccs_stretch_2 = np.mean(librosa.feature.mfcc(y=data_stretch_2, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch_2)
                    y_.append(p)
                    
                    data_pitch_shift = pitch_shift(data_x,3)
                    mfccs_stretch = np.mean(librosa.feature.melspectrogram(y=data_pitch_shift, sr=sampling_rate, n_mels=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append(p)
                    
    X_data = np.array(X_)
    y_data = np.array(y_)
    return X_data, y_data

# %%
x_mfccs, y = mfccs_feature_exteraction(audio_data)

# %%
#FEATURE EXTRACTION AND SELECTION DONE

# %%
def augmented_lables_count(lables):
    unique, counts = np.unique(lables, return_counts=True)
    data_count = dict(zip(unique, counts))

    data = data_count

    courses = list(data.keys())
    values = list(data.values())

    fig = plt.figure(figsize = (10, 5))

    # creating the bar plot
    plt.bar(courses, values, color =['orange','green','blue','red','yellow','black'],
            width = 0.4)

    plt.xlabel("Diseases")
    plt.ylabel("Count")
    plt.title("Count of each disease")
    plt.show()

    print (data_count)

# %%
augmented_lables_count(y)
# Out:
# {'Bronchiolitis': 174, 'COPD': 298, 'Healthy': 210, 'Pneumonia': 222, 'URTI': 138}

# %%
y_data_encode = y.reshape(y.shape[0],1)
y_data_encode = np.where(y_data_encode == 'COPD',np.array([1,0,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Bronchiolitis',np.array([0,1,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Pneumonia',np.array([0,0,1,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'URTI',np.array([0,0,0,1,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Healthy',np.array([0,0,0,0,1]).reshape(1,5) , y_data_encode)

Y_data = y_data_encode.astype('float64')

# %%
mfccs_features = np.array(x_mfccs)
lables = np.array(Y_data)

mfccs_features.shape , lables.shape
# Out:
# ((1042, 52), (1042, 5))

# %%
#PREPROCESSING DONE

# %%
mfcc_train, mfcc_val, lables_train, lables_val  = train_test_split(mfccs_features, lables, test_size=0.175, random_state=10)
mfcc_train, mfcc_test, lables_train, lables_test = train_test_split(mfcc_train, lables_train, test_size=0.075, random_state=10)

print (mfcc_train.shape, mfcc_val.shape, mfcc_test.shape)
print (lables_train.shape, lables_val.shape, lables_test.shape)
# Out:
# (794, 52) (183, 52) (65, 52)
# (794, 5) (183, 5) (65, 5)

# %%
def plot_loss_curves(history):

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()
  plt.grid()


  # Plot accuracy
  plt.figure()
  plt.grid()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
x_train_gru = np.expand_dims(mfcc_train,axis=1)
x_val_gru = np.expand_dims(mfcc_val,axis=1)
x_test_gru = np.expand_dims(mfcc_test,axis=1)

y_train_gru = np.expand_dims(lables_train,axis=1)
y_val_gru = np.expand_dims(lables_val,axis=1)
y_test_gru = np.expand_dims(lables_test,axis=1)

# %%
Input_Sample = Input(shape=(1,52))

model_conv = Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu')(Input_Sample)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_conv = Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu')(model_conv)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_2_1 = GRU(32,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_2 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_2_1)

model_3 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_3 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_3)

model_x = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_x = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_x)

model_add_1 = add([model_3,model_2,model_x])

model_5 = GRU(128,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_5 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_5)

model_6 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_6 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_6)

model_add_2 = add([model_5,model_6,model_2_1])


model_7 = Dense(32, activation=None)(model_add_2)
model_7 = LeakyReLU()(model_7)
model_7 = Dense(128, activation=None)(model_7)
model_7 = LeakyReLU()(model_7)

model_9 = Dense(64, activation=None)(model_add_2)
model_9 = LeakyReLU()(model_9)
model_9 = Dense(128, activation=None)(model_9)
model_9 = LeakyReLU()(model_9)

model_add_3 = add([model_7,model_9])

model_10 = Dense(64, activation=None)(model_add_3)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(32, activation=None)(model_10)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(5, activation="softmax")(model_10)

gru_model = Model(inputs=Input_Sample, outputs = model_10)

gru_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 1, 52)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 1, 256)            │          66,816 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_2               │ (None, 1, 256)            │               0 │ conv1d_2[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 1, 256)            │           1,024 │ max_pooling1d_2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 1, 512)            │         655,872 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_3               │ (None, 1, 512)            │               0 │ conv1d_3[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 1, 512)            │           2,048 │ max_pooling1d_3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_12 (GRU)                  │ (None, 1, 64)             │         110,976 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_10 (GRU)                  │ (None, 1, 32)             │          52,416 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_14 (GRU)                  │ (None, 1, 64)             │         110,976 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_13 (GRU)                  │ (None, 1, 128)            │          74,496 │ gru_12[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_11 (GRU)                  │ (None, 1, 128)            │          62,208 │ gru_10[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_15 (GRU)                  │ (None, 1, 128)            │          74,496 │ gru_14[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 1, 128)            │               0 │ gru_13[0][0],              │
# │                               │                           │                 │ gru_11[0][0], gru_15[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_16 (GRU)                  │ (None, 1, 128)            │          99,072 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_18 (GRU)                  │ (None, 1, 64)             │          37,248 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_17 (GRU)                  │ (None, 1, 32)             │          15,552 │ gru_16[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_19 (GRU)                  │ (None, 1, 32)             │           9,408 │ gru_18[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 1, 32)             │               0 │ gru_17[0][0],              │
# │                               │                           │                 │ gru_19[0][0], gru_10[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_7 (Dense)               │ (None, 1, 32)             │           1,056 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 1, 64)             │           2,112 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 1, 32)             │               0 │ dense_7[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 1, 64)             │               0 │ dense_9[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 1, 128)            │           4,224 │ leaky_re_lu_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 1, 128)            │           8,320 │ leaky_re_lu_8[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 1, 128)            │               0 │ dense_8[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 1, 128)            │               0 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 1, 128)            │               0 │ leaky_re_lu_7[0][0],       │
# │                               │                           │                 │ leaky_re_lu_9[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 1, 64)             │           8,256 │ add_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 1, 64)             │               0 │ dense_11[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 1, 32)             │           2,080 │ leaky_re_lu_10[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 1, 32)             │               0 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 1, 5)              │             165 │ leaky_re_lu_11[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,398,821 (5.34 MB)
#  Trainable params: 1,397,285 (5.33 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
#MODEL DEVELOPMENT DONE

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define optimizer
optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compile the model
gru_model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['accuracy'])

# Update the file path to use .keras format
filepath = 'C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras'

# Callbacks with updated file extension
cb = [
    EarlyStopping(patience=300, monitor='val_accuracy', mode='max', restore_best_weights=True),  # Early stopping
    ModelCheckpoint(filepath=filepath, 
                    monitor='val_accuracy', 
                    save_best_only=True, 
                    mode='max', 
                    verbose=1)  # Model checkpoint
]

# %%
history = gru_model.fit(x_train_gru, y_train_gru, batch_size=8, epochs=50, validation_data=(x_val_gru, y_val_gru), callbacks = cb)
# Out:
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3600 - loss: 1.4899
# Epoch 1: val_accuracy improved from -inf to 0.34973, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - accuracy: 0.3606 - loss: 1.4892 - val_accuracy: 0.3497 - val_loss: 1.5316
# Epoch 2/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4998 - loss: 1.2623
# Epoch 2: val_accuracy improved from 0.34973 to 0.51913, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.5002 - loss: 1.2614 - val_accuracy: 0.5191 - val_loss: 1.3123
# Epoch 3/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5582 - loss: 1.0917
# Epoch 3: val_accuracy improved from 0.51913 to 0.60656, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.5581 - loss: 1.0919 - val_accuracy: 0.6066 - val_loss: 1.1182
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6111 - loss: 1.0041
# Epoch 4: val_accuracy improved from 0.60656 to 0.65027, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.6112 - loss: 1.0039 - val_accuracy: 0.6503 - val_loss: 0.9628
# Epoch 5/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6245 - loss: 0.9265
# Epoch 5: val_accuracy did not improve from 0.65027
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6247 - loss: 0.9260 - val_accuracy: 0.6448 - val_loss: 0.8660
# Epoch 6/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6879 - loss: 0.8502
# Epoch 6: val_accuracy improved from 0.65027 to 0.69399, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.6874 - loss: 0.8507 - val_accuracy: 0.6940 - val_loss: 0.7557
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6658 - loss: 0.8168
# Epoch 7: val_accuracy improved from 0.69399 to 0.74317, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.6658 - loss: 0.8167 - val_accuracy: 0.7432 - val_loss: 0.6775
# Epoch 8/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6711 - loss: 0.8098
# Epoch 8: val_accuracy did not improve from 0.74317
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6716 - loss: 0.8091 - val_accuracy: 0.7158 - val_loss: 0.7325
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6847 - loss: 0.7731
# Epoch 9: val_accuracy did not improve from 0.74317
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.6846 - loss: 0.7734 - val_accuracy: 0.7158 - val_loss: 0.6619
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6414 - loss: 0.8314
# Epoch 10: val_accuracy did not improve from 0.74317
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6418 - loss: 0.8308 - val_accuracy: 0.7158 - val_loss: 0.7026
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7259 - loss: 0.7102
# Epoch 11: val_accuracy improved from 0.74317 to 0.74863, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.7259 - loss: 0.7102 - val_accuracy: 0.7486 - val_loss: 0.6572
# Epoch 12/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7209 - loss: 0.7223
# Epoch 12: val_accuracy did not improve from 0.74863
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7209 - loss: 0.7218 - val_accuracy: 0.7432 - val_loss: 0.6225
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7505 - loss: 0.6473
# Epoch 13: val_accuracy did not improve from 0.74863
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.7504 - loss: 0.6474 - val_accuracy: 0.7049 - val_loss: 0.6678
# Epoch 14/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7386 - loss: 0.6309
# Epoch 14: val_accuracy improved from 0.74863 to 0.75956, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.7385 - loss: 0.6316 - val_accuracy: 0.7596 - val_loss: 0.5935
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7296 - loss: 0.6987
# Epoch 15: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7297 - loss: 0.6983 - val_accuracy: 0.7377 - val_loss: 0.6059
# Epoch 16/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7455 - loss: 0.5961
# Epoch 16: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7456 - loss: 0.5965 - val_accuracy: 0.7322 - val_loss: 0.6706
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7153 - loss: 0.6576
# Epoch 17: val_accuracy improved from 0.75956 to 0.76503, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.7155 - loss: 0.6574 - val_accuracy: 0.7650 - val_loss: 0.6198
# Epoch 18/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7705 - loss: 0.6282
# Epoch 18: val_accuracy improved from 0.76503 to 0.77596, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7703 - loss: 0.6282 - val_accuracy: 0.7760 - val_loss: 0.5598
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7713 - loss: 0.6284
# Epoch 19: val_accuracy did not improve from 0.77596
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7713 - loss: 0.6284 - val_accuracy: 0.7705 - val_loss: 0.5506
# Epoch 20/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7637 - loss: 0.6219
# Epoch 20: val_accuracy improved from 0.77596 to 0.80328, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.7637 - loss: 0.6217 - val_accuracy: 0.8033 - val_loss: 0.5071
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7839 - loss: 0.5951
# Epoch 21: val_accuracy did not improve from 0.80328
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7838 - loss: 0.5950 - val_accuracy: 0.7978 - val_loss: 0.5105
# Epoch 22/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7613 - loss: 0.6026
# Epoch 22: val_accuracy improved from 0.80328 to 0.81967, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.7616 - loss: 0.6022 - val_accuracy: 0.8197 - val_loss: 0.4885
# Epoch 23/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7914 - loss: 0.5205
# Epoch 23: val_accuracy did not improve from 0.81967
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7913 - loss: 0.5209 - val_accuracy: 0.7814 - val_loss: 0.5307
# Epoch 24/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7692 - loss: 0.6078
# Epoch 24: val_accuracy did not improve from 0.81967
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7692 - loss: 0.6078 - val_accuracy: 0.7978 - val_loss: 0.5612
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7875 - loss: 0.5701
# Epoch 25: val_accuracy did not improve from 0.81967
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7875 - loss: 0.5700 - val_accuracy: 0.7923 - val_loss: 0.5179
# Epoch 26/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8010 - loss: 0.5363
# Epoch 26: val_accuracy improved from 0.81967 to 0.83060, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8009 - loss: 0.5363 - val_accuracy: 0.8306 - val_loss: 0.4781
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7917 - loss: 0.5207
# Epoch 27: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.7917 - loss: 0.5209 - val_accuracy: 0.7814 - val_loss: 0.5591
# Epoch 28/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7869 - loss: 0.5489
# Epoch 28: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.7868 - loss: 0.5490 - val_accuracy: 0.8033 - val_loss: 0.5090
# Epoch 29/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8154 - loss: 0.4953
# Epoch 29: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8153 - loss: 0.4957 - val_accuracy: 0.8033 - val_loss: 0.4658
# Epoch 30/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8148 - loss: 0.4913
# Epoch 30: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8146 - loss: 0.4916 - val_accuracy: 0.7377 - val_loss: 0.5712
# Epoch 31/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8361 - loss: 0.4406
# Epoch 31: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8355 - loss: 0.4420 - val_accuracy: 0.7869 - val_loss: 0.5014
# Epoch 32/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7928 - loss: 0.5283
# Epoch 32: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7930 - loss: 0.5280 - val_accuracy: 0.8033 - val_loss: 0.4300
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8068 - loss: 0.4976
# Epoch 33: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8066 - loss: 0.4979 - val_accuracy: 0.7377 - val_loss: 0.6419
# Epoch 34/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7980 - loss: 0.5137
# Epoch 34: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7983 - loss: 0.5134 - val_accuracy: 0.7978 - val_loss: 0.5197
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7975 - loss: 0.5738
# Epoch 35: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7976 - loss: 0.5735 - val_accuracy: 0.8142 - val_loss: 0.5008
# Epoch 36/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8148 - loss: 0.5003
# Epoch 36: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8149 - loss: 0.4999 - val_accuracy: 0.7923 - val_loss: 0.4559
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8049 - loss: 0.4758
# Epoch 37: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8050 - loss: 0.4758 - val_accuracy: 0.8142 - val_loss: 0.4657
# Epoch 38/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8014 - loss: 0.4824
# Epoch 38: val_accuracy did not improve from 0.83060
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8015 - loss: 0.4824 - val_accuracy: 0.8087 - val_loss: 0.4685
# Epoch 39/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8282 - loss: 0.4231
# Epoch 39: val_accuracy improved from 0.83060 to 0.84153, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8280 - loss: 0.4236 - val_accuracy: 0.8415 - val_loss: 0.4276
# Epoch 40/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8182 - loss: 0.4465
# Epoch 40: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8183 - loss: 0.4464 - val_accuracy: 0.8197 - val_loss: 0.4830
# Epoch 41/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8191 - loss: 0.4576
# Epoch 41: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8192 - loss: 0.4575 - val_accuracy: 0.8142 - val_loss: 0.4396
# Epoch 42/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8312 - loss: 0.4188
# Epoch 42: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8313 - loss: 0.4188 - val_accuracy: 0.8033 - val_loss: 0.4457
# Epoch 43/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8017 - loss: 0.5079
# Epoch 43: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8021 - loss: 0.5069 - val_accuracy: 0.8415 - val_loss: 0.3801
# Epoch 44/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8286 - loss: 0.4594
# Epoch 44: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8285 - loss: 0.4596 - val_accuracy: 0.8361 - val_loss: 0.4192
# Epoch 45/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8286 - loss: 0.4577
# Epoch 45: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8285 - loss: 0.4578 - val_accuracy: 0.8087 - val_loss: 0.5217
# Epoch 46/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8410 - loss: 0.4269
# Epoch 46: val_accuracy improved from 0.84153 to 0.84699, saving model to C:/Users/saive/Desktop/RESPIRE/Respiratory_Sound_Database/dir/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8407 - loss: 0.4274 - val_accuracy: 0.8470 - val_loss: 0.4248
# Epoch 47/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8139 - loss: 0.4401
# Epoch 47: val_accuracy did not improve from 0.84699
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8139 - loss: 0.4405 - val_accuracy: 0.8197 - val_loss: 0.4593
# Epoch 48/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8252 - loss: 0.4556
# Epoch 48: val_accuracy did not improve from 0.84699
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8253 - loss: 0.4554 - val_accuracy: 0.8415 - val_loss: 0.4087
# Epoch 49/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8297 - loss: 0.4364
# Epoch 49: val_accuracy did not improve from 0.84699
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8297 - loss: 0.4364 - val_accuracy: 0.8415 - val_loss: 0.4026
# Epoch 50/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8491 - loss: 0.3853
# Epoch 50: val_accuracy did not improve from 0.84699
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8488 - loss: 0.3861 - val_accuracy: 0.8251 - val_loss: 0.4263

# %%
gru_model.evaluate(x_train_gru, y_train_gru)

plot_loss_curves(history)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3291

# %%
#MODEL VALIDATION AND OPTIMISATION DONE

# %%
classes = ["COPD" ,"Bronchiolitis ", "Pneumoina", "URTI", "Healthy"]
preds = gru_model.predict(x_test_gru)
classpreds = [np.argmax(t) for t in preds ]
y_testclass = [np.argmax(t) for t in y_test_gru]
cm = confusion_matrix(y_testclass, classpreds)
plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
ax = sns.heatmap(cm, cmap='Blues', annot=True, fmt='d', xticklabels=classes, yticklabels=classes)
plt.title('')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step

# %%
print(classification_report(y_testclass, classpreds, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#           COPD       1.00      0.92      0.96        25
# Bronchiolitis        0.69      1.00      0.82         9
#      Pneumoina       0.88      0.70      0.78        10
#           URTI       0.50      0.25      0.33         4
#        Healthy       0.74      0.82      0.78        17
#
#       accuracy                           0.83        65
#      macro avg       0.76      0.74      0.73        65
#   weighted avg       0.84      0.83      0.83        65

# %%
def gru_diagnosis_prediction(test_audio):
    data_x, sampling_rate = librosa.load(test_audio)
    data_x = stretch (data_x,1.2)

    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=52).T,axis = 0)

    features = features.reshape(1,52)

    test_pred = gru_model.predict(np.expand_dims(features, axis = 1))
    classpreds = classes[np.argmax(test_pred[0], axis=1)[0]]
    confidence = test_pred.T[test_pred[0].mean(axis=0).argmax()].mean()

    print (classpreds , confidence)

# %%
val = []
dir_ = r"C:\Users\saive\Desktop\RESPIRE\Respiratory_Sound_Database\dir\audio files\137_1b1_Ll_sc_Meditron.wav"  
features = 52

data_x, sampling_rate = librosa.load(dir_, res_type='kaiser_fast') # Use dir_ directly
mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T, axis=0)
val.append(mfccs)
val = np.expand_dims(np.array(val), axis=0) 
print(val.shape) # Output: (1, 1, 52)
# Out:
# (1, 1, 52)

# %%
classes[np.argmax(gru_model.predict(val))]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 'URTI'
